# %%
import pandas as pd

# we use this model for linear regression
from sklearn.linear_model import LinearRegression

data = pd.read_csv("../crypto_data/btc-usd-max.csv")

data['price']
# Out:
# 0         135.30000
# 1         141.96000
# 2         135.30000
# 3         117.00000
# 4         103.43000
#            ...
# 4064    66011.07874
# 4065    66190.48749
# 4066    66615.53782
# 4067    66460.38898
# 4068    65109.31481
# Name: price, Length: 4069, dtype: float64

# %%
data
# Out:
#                    snapped_at        price    market_cap  total_volume
# 0     2013-04-28 00:00:00 UTC    135.30000  1.500518e+09  0.000000e+00
# 1     2013-04-29 00:00:00 UTC    141.96000  1.575032e+09  0.000000e+00
# 2     2013-04-30 00:00:00 UTC    135.30000  1.501657e+09  0.000000e+00
# 3     2013-05-01 00:00:00 UTC    117.00000  1.298952e+09  0.000000e+00
# 4     2013-05-02 00:00:00 UTC    103.43000  1.148668e+09  0.000000e+00
# ...                       ...          ...           ...           ...
# 4064  2024-06-15 00:00:00 UTC  66011.07874  1.301950e+12  2.796699e+10
# 4065  2024-06-16 00:00:00 UTC  66190.48749  1.304370e+12  1.347273e+10
# 4066  2024-06-17 00:00:00 UTC  66615.53782  1.313850e+12  1.265013e+10
# 4067  2024-06-18 00:00:00 UTC  66460.38898  1.309330e+12  2.940973e+10
# 4068  2024-06-19 00:00:00 UTC  65109.31481  1.282300e+12  4.138697e+10
#
# [4069 rows x 4 columns]

# %%
data['price'] = pd.to_numeric(data['price'], errors = 'coerce')

data['snapped_at'] = pd.to_datetime(data['snapped_at'])

data['timestamp'] = data['snapped_at'].astype('int64') // 10**9 #convert to seconds

data['timestamp']
# Out:
# 0       1367107200
# 1       1367193600
# 2       1367280000
# 3       1367366400
# 4       1367452800
#            ...
# 4064    1718409600
# 4065    1718496000
# 4066    1718582400
# 4067    1718668800
# 4068    1718755200
# Name: timestamp, Length: 4069, dtype: int64

# %%
# now to try and train a model that would tell us future prices.

X = data[['timestamp']]
y = data['price']

model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
# Make predictions with feature names
predictions = model.predict(pd.DataFrame([[2050], [2070], [2030], [2032]], columns=['timestamp']))

# Print predictions
print(predictions)

# this code is just rubbish it does nothing for now but we have gotten the general process so we can refine and learn how to do this process better and better over time
# Out:
# [-204212.4275569  -204212.42471934 -204212.43039446 -204212.4301107 ]
